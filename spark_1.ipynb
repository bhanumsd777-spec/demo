# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanumsd777-spec/demo/blob/main/spark_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd

# %%
df=pd.read_csv('/content/test1.csv')
df.head(2) #five
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   age         6 non-null      int64
#  2   Experience  6 non-null      int64
#  3   Salary      6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes

# %%
print(__builtins__.type(pd.read_csv('/content/test1.csv')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('demo').getOrCreate()

# %%
df=spark.read.csv('/content/test1.csv')

# %%
df.show
# Out:
# <bound method DataFrame.show of DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]>

# %%
df=spark.read.option('header','true').csv('test1.csv')

# %%
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df.head()
# Out:
# Row(Name='Ben', age='31', Experience='10', Salary='30000')
